# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler

# %%
df = pd.read_csv('loan_sanction.csv')

# %% [markdown]
# ## Converting to binary

# %%
#Gender - convert to binary
#Male - 1, Female - 0
def gender_map(x):
    if x == "Male":
        return 1
    if x == "Female":
        return 0

df["Gender"] = df["Gender"].map(gender_map)
print(df["Gender"])
# Out:
# 0      1.0
# 1      1.0
# 2      1.0
# 3      1.0
# 4      1.0
#       ...
# 609    0.0
# 610    1.0
# 611    1.0
# 612    1.0
# 613    0.0
# Name: Gender, Length: 614, dtype: float64

# %%
#Married - convert to binary
#Yes - 1, No - 0
def married_map(x):
    if x == "Yes":
        return 1
    if x == "No":
        return 0

df["Married"] = df["Married"].map(married_map)

print(df["Married"])
# Out:
# 0      0.0
# 1      1.0
# 2      1.0
# 3      1.0
# 4      0.0
#       ...
# 609    0.0
# 610    1.0
# 611    1.0
# 612    1.0
# 613    0.0
# Name: Married, Length: 614, dtype: float64

# %%
#Dependents - change 3+ to 3
def dep_map (x):
    if x == 0:
        return 0
    if x == 1:
        return 1
    if x == 2:
        return 2
    if x == "3+":
        return 3
    return 0
df["Dependents"] = df["Dependents"].map(dep_map)
df['Dependents'] = df['Dependents'].astype(str).astype(int)

# %%
#Education - convert to binary
#Graduate - 1, Not Graduate - 0
def edu_map(x):
    if x == "Graduate":
        return 1
    if x == "Not Graduate":
        return 0
    return None

df["Education"] = df["Education"].map(edu_map)
print(df["Education"])
# Out:
# 0      1
# 1      1
# 2      1
# 3      0
# 4      1
#       ..
# 609    1
# 610    1
# 611    1
# 612    1
# 613    1
# Name: Education, Length: 614, dtype: int64

# %%
#Self_Employed - convert to binary
#Yes - 1, No - 0
def self_emp_map(x):
    if x == "Yes":
        return 1
    if x == "No":
        return 0
    return None

df["Self_Employed"] = df["Self_Employed"].map(self_emp_map)
print(df["Self_Employed"])
# Out:
# 0      0.0
# 1      0.0
# 2      1.0
# 3      0.0
# 4      0.0
#       ...
# 609    0.0
# 610    0.0
# 611    0.0
# 612    0.0
# 613    1.0
# Name: Self_Employed, Length: 614, dtype: float64

# %%
#Property Area - convert to 1 to 3
#1 - urban, 2 - semiurban, 3 - rural
def prop_map(x):
    if x == "Urban":
        return 1
    if x == "Semiurban":
        return 2
    if x == "Rural":
        return 3
    return None

df["Property_Area"] = df["Property_Area"].map(prop_map)
print(df["Property_Area"])
# Out:
# 0      1
# 1      3
# 2      1
# 3      1
# 4      1
#       ..
# 609    3
# 610    3
# 611    1
# 612    1
# 613    2
# Name: Property_Area, Length: 614, dtype: int64

# %%
#Loan Status - convert to binary
#Y - 1, N - 0
def loan_map(x):
    if x == "Y":
        return 1
    if x == "N":
        return 0
    return None

df["Loan_Status"] = df["Loan_Status"].map(loan_map)
print(df["Loan_Status"])
# Out:
# 0      1
# 1      0
# 2      1
# 3      1
# 4      1
#       ..
# 609    1
# 610    1
# 611    1
# 612    1
# 613    0
# Name: Loan_Status, Length: 614, dtype: int64

# %%
print(df.info())
df.corr()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 614 entries, 0 to 613
# Data columns (total 13 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Loan_ID            614 non-null    object
#  1   Gender             601 non-null    float64
#  2   Married            611 non-null    float64
#  3   Dependents         614 non-null    int32
#  4   Education          614 non-null    int64
#  5   Self_Employed      582 non-null    float64
#  6   ApplicantIncome    614 non-null    int64
#  7   CoapplicantIncome  614 non-null    float64
#  8   LoanAmount         592 non-null    float64
#  9   Loan_Amount_Term   600 non-null    float64
#  10  Credit_History     564 non-null    float64
#  11  Property_Area      614 non-null    int64
#  12  Loan_Status        614 non-null    int64
# dtypes: float64(7), int32(1), int64(4), object(1)
# memory usage: 60.1+ KB
# None
#                      Gender   Married  Dependents  Education  Self_Employed  \
# Gender             1.000000  0.369612    0.093710  -0.049258      -0.009829
# Married            0.369612  1.000000    0.133848  -0.014223       0.001909
# Dependents         0.093710  0.133848    1.000000  -0.055288       0.001711
# Education         -0.049258 -0.014223   -0.055288   1.000000       0.012333
# Self_Employed     -0.009829  0.001909    0.001711   0.012333       1.000000
# ApplicantIncome    0.053989  0.051332    0.156687   0.140760       0.140826
# CoapplicantIncome  0.083946  0.077770    0.041491   0.062290      -0.011152
# LoanAmount         0.106947  0.149519    0.156271   0.171133       0.123931
# Loan_Amount_Term  -0.075117 -0.103810   -0.077850   0.078784      -0.037069
# Credit_History     0.016337  0.004381   -0.059706   0.081822       0.003883
# Property_Area      0.024556 -0.002918    0.051830  -0.065243       0.031214
# Loan_Status        0.019857  0.089280   -0.026123   0.085884      -0.002303
#
#                    ApplicantIncome  CoapplicantIncome  LoanAmount  \
# Gender                    0.053989           0.083946    0.106947
# Married                   0.051332           0.077770    0.149519
# Dependents                0.156687           0.041491    0.156271
# Education                 0.140760           0.062290    0.171133
# Self_Employed             0.140826          -0.011152    0.123931
# ApplicantIncome           1.000000          -0.116605    0.570909
# CoapplicantIncome        -0.116605           1.000000    0.188619
# LoanAmount                0.570909           0.188619    1.000000
# Loan_Amount_Term         -0.045306          -0.059878    0.039447
# Credit_History           -0.014715          -0.002056   -0.008433
# Property_Area             0.009500          -0.010522    0.045792
# Loan_Status              -0.004710          -0.059187   -0.037318
#
#                    Loan_Amount_Term  Credit_History  Property_Area  \
# Gender                    -0.075117        0.016337       0.024556
# Married                   -0.103810        0.004381      -0.002918
# Dependents                -0.077850       -0.059706       0.051830
# Education                  0.078784        0.081822      -0.065243
# Self_Employed             -0.037069        0.003883       0.031214
# ApplicantIncome           -0.045306       -0.014715       0.009500
# CoapplicantIncome         -0.059878       -0.002056      -0.010522
# LoanAmount                 0.039447       -0.008433       0.045792
# Loan_Amount_Term           1.000000        0.001470       0.078748
# Credit_History             0.001470        1.000000       0.001969
# Property_Area              0.078748        0.001969       1.000000
# Loan_Status               -0.021268        0.561678      -0.032112
#
#                    Loan_Status
# Gender                0.019857
# Married               0.089280
# Dependents           -0.026123
# Education             0.085884
# Self_Employed        -0.002303
# ApplicantIncome      -0.004710
# CoapplicantIncome    -0.059187
# LoanAmount           -0.037318
# Loan_Amount_Term     -0.021268
# Credit_History        0.561678
# Property_Area        -0.032112
# Loan_Status           1.000000
