# %% [markdown]
# # **Question 4 - Rebuild the models**
# - Which attributes relate strongly to the outcome of loan status?
# - using Random Forest

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ## Prepare data for training and test

# %%
#import X and y from data_cleaning.ipynb
# %store -r X
# %store -r y

#Use only the selected features
selected_features = ['CoapplicantIncome', 'LoanAmount', 'Loan_Amount_Term','Credit_History_0.0', 'Credit_History_1.0']
X = X[selected_features]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)
print(X_train.head())
print(y_train.head())
# Out:
#      CoapplicantIncome  LoanAmount  Loan_Amount_Term  Credit_History_0.0  \
# 479             0.2812      0.5651            0.7436                   0
# 419             0.2486      0.5243            0.7436                   0
# 66              0.3954      0.4660            0.3590                   1
# 376             0.8763      0.4854            0.7436                   0
# 29              0.3654      0.4369            0.7436                   0
#
#      Credit_History_1.0
# 479                   1
# 419                   1
# 66                    0
# 376                   1
# 29                    1
# 479    N
# 419    Y
# 66     N
# 376    Y
# 29     Y
# Name: Loan_Status, dtype: object

# %% [markdown]
# # **Decision Tree**

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, confusion_matrix
dt = DecisionTreeClassifier(criterion='entropy', max_depth=3)
dt.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=3)

# %%
#Visualize the tree with features name
from sklearn import tree
features = X.columns
class_names = ['N', 'Y']
plt.figure(figsize=(15,10))
tree.plot_tree(dt, feature_names=X.columns, filled=True, fontsize=10)
plt.show()

#Predict the test set results
y_pred = dt.predict(X_test)

#Creates confusion matrix
cm = confusion_matrix(y_test, y_pred)
print("-----------\n")
print(cm)

#Transform to df for easier plotting
cm_df = pd.DataFrame(cm, index = ['N', 'Y'], columns = ['N', 'Y'])

#Print confusion matrix as heatmap
plt.figure(figsize=(5.5, 4))
sns.heatmap(cm_df, annot = True)
plt.title('Decision Tree \nAccuracy:{0:.4f}'.format(accuracy_score(y_test, y_pred)))
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()
# Out:
# -----------
#
# [[ 31  25]
#  [  3 104]]

# %% [markdown]
# # **Naive Bayes**

# %%
from sklearn.naive_bayes import GaussianNB
NB = GaussianNB()
NB.fit(X_train, y_train)
y_pred = NB.predict(X_test)

# %%
#classification report
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred))

#Creates confusion matrix
cm = confusion_matrix(y_test, y_pred)
print("-----------\n")
print(cm)

#Transform to df for easier plotting
cm_df = pd.DataFrame(cm, index = ['N', 'Y'], columns = ['N', 'Y'])

#Print confusion matrix as heatmap
plt.figure(figsize=(5.5, 4))
sns.heatmap(cm_df, annot = True)
plt.title('Naive Bayes \nAccuracy:{0:.4f}'.format(accuracy_score(y_test, y_pred)))
plt.ylabel('True label')
plt.xlabel('Predicted label')
plt.show()
# Out:
#               precision    recall  f1-score   support
#
#            N       0.97      0.57      0.72        56
#            Y       0.82      0.99      0.89       107
#
#     accuracy                           0.85       163
#    macro avg       0.89      0.78      0.81       163
# weighted avg       0.87      0.85      0.83       163
#
# -----------
#
# [[ 32  24]
#  [  1 106]]

# %% [markdown]
# # **Neural Network**

# %%
from keras.models import Sequential
from keras.layers import Dense

model = Sequential()
model.add(Dense(20, input_dim = 5, activation = "relu"))
model.add(Dense(16, activation = "relu"))
model.add(Dense(1, activation = 'sigmoid'))

#transform Y, N to 0, 1
y_train = y_train.replace({'N':0, 'Y':1})
y_test = y_test.replace({'N':0, 'Y':1})

# %%
#compile the model
model.compile(loss = 'binary_crossentropy', optimizer = 'adam', metrics = ['accuracy'])

#train the model
model.fit(X_train, y_train, epochs = 100, batch_size = 10)
# Out:
# Epoch 1/100
# 38/38 [==============================] - 1s 2ms/step - loss: 0.5744 - accuracy: 0.7116
# Epoch 2/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5420 - accuracy: 0.7196
# Epoch 3/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.5170 - accuracy: 0.7937
# Epoch 4/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4953 - accuracy: 0.8148
# Epoch 5/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4829 - accuracy: 0.8148
# Epoch 6/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4788 - accuracy: 0.8148
# Epoch 7/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4757 - accuracy: 0.8148
# Epoch 8/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4714 - accuracy: 0.8148
# Epoch 9/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4706 - accuracy: 0.8148
# Epoch 10/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4700 - accuracy: 0.8148
# Epoch 11/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4706 - accuracy: 0.8148
# Epoch 12/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4689 - accuracy: 0.8148
# Epoch 13/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4697 - accuracy: 0.8148
# Epoch 14/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4705 - accuracy: 0.8148
# Epoch 15/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4701 - accuracy: 0.8148
# Epoch 16/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4692 - accuracy: 0.8148
# Epoch 17/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4706 - accuracy: 0.8148
# Epoch 18/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4691 - accuracy: 0.8148
# Epoch 19/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4687 - accuracy: 0.8148
# Epoch 20/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4695 - accuracy: 0.8148
# Epoch 21/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4700 - accuracy: 0.8148
# Epoch 22/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4683 - accuracy: 0.8148
# Epoch 23/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4673 - accuracy: 0.8148
# Epoch 24/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4674 - accuracy: 0.8148
# Epoch 25/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4685 - accuracy: 0.8148
# Epoch 26/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4675 - accuracy: 0.8148
# Epoch 27/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4674 - accuracy: 0.8148
# Epoch 28/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4683 - accuracy: 0.8148
# Epoch 29/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4671 - accuracy: 0.8148
# Epoch 30/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4709 - accuracy: 0.8148
# Epoch 31/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4683 - accuracy: 0.8148
# Epoch 32/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4682 - accuracy: 0.8148
# Epoch 33/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4678 - accuracy: 0.8148
# Epoch 34/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4672 - accuracy: 0.8148
# Epoch 35/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4664 - accuracy: 0.8148
# Epoch 36/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4658 - accuracy: 0.8148
# Epoch 37/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4656 - accuracy: 0.8148
# Epoch 38/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4657 - accuracy: 0.8148
# Epoch 39/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4659 - accuracy: 0.8148
# Epoch 40/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4663 - accuracy: 0.8148
# Epoch 41/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4659 - accuracy: 0.8148
# Epoch 42/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4653 - accuracy: 0.8148
# Epoch 43/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4660 - accuracy: 0.8148
# Epoch 44/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4674 - accuracy: 0.8148
# Epoch 45/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4650 - accuracy: 0.8148
# Epoch 46/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4652 - accuracy: 0.8148
# Epoch 47/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4650 - accuracy: 0.8148
# Epoch 48/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4663 - accuracy: 0.8148
# Epoch 49/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4688 - accuracy: 0.8148
# Epoch 50/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4661 - accuracy: 0.8148
# Epoch 51/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4652 - accuracy: 0.8148
# Epoch 52/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4651 - accuracy: 0.8148
# Epoch 53/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4649 - accuracy: 0.8148
# Epoch 54/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4667 - accuracy: 0.8148
# Epoch 55/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4687 - accuracy: 0.8148
# Epoch 56/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4644 - accuracy: 0.8148
# Epoch 57/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4669 - accuracy: 0.8148
# Epoch 58/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4672 - accuracy: 0.8148
# Epoch 59/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4644 - accuracy: 0.8148
# Epoch 60/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4638 - accuracy: 0.8148
# Epoch 61/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4646 - accuracy: 0.8148
# Epoch 62/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4641 - accuracy: 0.8148
# Epoch 63/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4644 - accuracy: 0.8148
# Epoch 64/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4649 - accuracy: 0.8148
# Epoch 65/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4641 - accuracy: 0.8148
# Epoch 66/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4638 - accuracy: 0.8148
# Epoch 67/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4643 - accuracy: 0.8148
# Epoch 68/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4639 - accuracy: 0.8148
# Epoch 69/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4684 - accuracy: 0.8148
# Epoch 70/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4652 - accuracy: 0.8148
# Epoch 71/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4640 - accuracy: 0.8148
# Epoch 72/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4643 - accuracy: 0.8148
# Epoch 73/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4630 - accuracy: 0.8148
# Epoch 74/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4625 - accuracy: 0.8148
# Epoch 75/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4631 - accuracy: 0.8148
# Epoch 76/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4634 - accuracy: 0.8148
# Epoch 77/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4631 - accuracy: 0.8148
# Epoch 78/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4646 - accuracy: 0.8148
# Epoch 79/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4621 - accuracy: 0.8148
# Epoch 80/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4630 - accuracy: 0.8148
# Epoch 81/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4616 - accuracy: 0.8148
# Epoch 82/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4629 - accuracy: 0.8148
# Epoch 83/100
# 38/38 [==============================] - 0s 1ms/step - loss: 0.4627 - accuracy: 0.8148
# Epoch 84/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4612 - accuracy: 0.8148
# Epoch 85/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4654 - accuracy: 0.8148
# Epoch 86/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4629 - accuracy: 0.8148
# Epoch 87/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4616 - accuracy: 0.8148
# Epoch 88/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4624 - accuracy: 0.8148
# Epoch 89/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4622 - accuracy: 0.8148
# Epoch 90/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4623 - accuracy: 0.8148
# Epoch 91/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4629 - accuracy: 0.8148
# Epoch 92/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4624 - accuracy: 0.8148
# Epoch 93/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4610 - accuracy: 0.8148
# Epoch 94/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4631 - accuracy: 0.8148
# Epoch 95/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4615 - accuracy: 0.8148
# Epoch 96/100
# 38/38 [==============================] - 0s 3ms/step - loss: 0.4613 - accuracy: 0.8148
# Epoch 97/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4615 - accuracy: 0.8148
# Epoch 98/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4637 - accuracy: 0.8148
# Epoch 99/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4617 - accuracy: 0.8148
# Epoch 100/100
# 38/38 [==============================] - 0s 2ms/step - loss: 0.4612 - accuracy: 0.8148

# %%
#evaluate the model
score = model.evaluate(X_test, y_test)
print('Test loss: ', score[0])
print('Test accuracy: ', score[1])
print("\n")
# Out:
# 6/6 [==============================] - 0s 2ms/step - loss: 0.4048 - accuracy: 0.8466
# Test loss:  0.4048301875591278
# Test accuracy:  0.8466257452964783
